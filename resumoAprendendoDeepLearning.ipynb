# %% [markdown]
# <a href="https://colab.research.google.com/github/adalbertobrant/aprendendoDeepLearning/blob/master/resumoAprendendoDeepLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
import torch
from PIL import Image
from torchvision import models
from torchvision import transforms
alexnet = models.AlexNet()
resnet = models.resnet101(pretrained=True)
preprocess = transforms.Compose([
  transforms.Resize(256),
  transforms.CenterCrop(224),
  transforms.ToTensor(),
  transforms.Normalize(
  mean=[0.485, 0.456, 0.406],
  std=[0.229, 0.224, 0.225]
  )])
pastor = Image.open('/content/drive/My Drive/imagegooglecolab/pastor.jpg')
cobra = Image.open('/content/drive/My Drive/imagegooglecolab/snake.jpg')
img_t = preprocess(pastor)
img_cobra = preprocess(cobra)
batch_t = torch.unsqueeze(img_t, 0)
batch_cobra = torch.unsqueeze(img_cobra,0)
resnet.eval()
out = resnet(batch_t)
out2 = resnet(batch_cobra)
with open('/content/drive/My Drive/imagegooglecolab/imagenet_classes.txt') as f:
  labels = [line.strip() for line in f.readlines()]
_, index = torch.max(out2, 1)
_, indice = torch.max(out,1)
percentage = torch.nn.functional.softmax(out, dim=1)[0] * 100
percentage1 = torch.nn.functional.softmax(out2, dim=1)[0]* 100

#imagem_pastor = labels[indice[0]], percentage[indice[0]].item()
image_cobra = labels[index[0]], percentage1[index[0]].item()
print(image_cobra)
cobra
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ('rock python, rock snake, Python sebae', 34.85695266723633)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=257x180 at 0x7F9BCA6C5EF0>
